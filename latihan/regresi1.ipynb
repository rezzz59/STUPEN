# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 1. TARIK DATA DARI SUMBER PUBLIK (UCI Repository)
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data"

# Karena file aslinya polosan (gak ada header), kita buat daftar nama kolomnya dulu
cols = [
    "symboling", "normalized-losses", "make", "fuel-type", "aspiration",
    "num-of-doors", "body-style", "drive-wheels", "engine-location", "wheel-base",
    "length", "width", "height", "curb-weight", "engine-type",
    "num-of-cylinders", "engine-size", "fuel-system", "bore", "stroke",
    "compression-ratio", "horsepower", "peak-rpm", "city-mpg", "highway-mpg", "price"
]

# Baca data csv
df_auto = pd.read_csv(url, names=cols)

# 2. CEK KEKOTORAN DATA
print("--- Info Dataset ---")
print(df_auto.info())

print("\n--- Intip 10 Baris Pertama ---")
display(df_auto.head(10))

print("\n--- Cek Statistik Dasar ---")
# Hati-hati, describe() cuma akan menghitung kolom yang dianggap ANGKA oleh Pandas
display(df_auto.describe())
# Out:
# /home/ahmad/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# --- Info Dataset ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
# ...

# %%
df_auto
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df_auto.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
df_auto
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
import numpy as np

df_auto.replace('?', np.nan, inplace=True)
df_auto
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df_auto.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
df_auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
numeric_cols = ['normalized-losses', 'bore', 'stroke', 'horsepower', 'peak-rpm', 'price']


for col in numeric_cols:
    df_auto[col] = pd.to_numeric(df_auto[col], errors='coerce')
df_auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df_auto.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
df_auto = df_auto.dropna(subset=['price'], axis=0)

# %%
df_auto.isnull().sum()
# Out:
# symboling             0
# normalized-losses    37
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
df_auto.select_dtypes(include=['float64', 'int64']).mean()
# Out:
# symboling                0.840796
# normalized-losses      122.000000
# wheel-base              98.797015
# length                 174.200995
# width                   65.889055
# height                  53.766667
# curb-weight           2555.666667
# engine-size            126.875622
# bore                     3.330711
# stroke                   3.256904
# compression-ratio       10.164279
# horsepower             103.396985
# peak-rpm              5117.587940
# city-mpg                25.179104
# highway-mpg             30.686567
# price                13207.129353
# dtype: float64

# %%
df_auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 201 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               201 non-null    object
#  3   fuel-type          201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num-of-doors       199 non-null    object
#  6   body-style         201 non-null    object
#  7   drive-wheels       201 non-null    object
#  8   engine-location    201 non-null    object
#  9   wheel-base         201 non-null    float64
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb-weight        201 non-null    int64
#  14  engine-type        201 non-null    object
#  15  num-of-cylinders   201 non-null    object
# ...

# %%
numerical = df_auto.select_dtypes(include='number').columns
numerical
# Out:
# Index(['symboling', 'normalized-losses', 'wheel-base', 'length', 'width',
#        'height', 'curb-weight', 'engine-size', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

plt.figure(figsize=(13, 30))
for i, col in enumerate(numerical):
  plt.subplot(6, 4, i + 1)
  sns.histplot(df_auto[col])
plt.tight_layout()
plt.show()

# %%
df_auto['symboling'] = df_auto['symboling'].fillna(df_auto['symboling'].mean())
df_auto['bore'] = df_auto['bore'].fillna(df_auto['bore'].mean())
df_auto['stroke'] = df_auto['stroke'].fillna(df_auto['stroke'].mean())
# Out:
# /tmp/ipykernel_8630/3027481803.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_auto['symboling'] = df_auto['symboling'].fillna(df_auto['symboling'].mean())
# /tmp/ipykernel_8630/3027481803.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_auto['bore'] = df_auto['bore'].fillna(df_auto['bore'].mean())
# /tmp/ipykernel_8630/3027481803.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_auto['normalized-losses'] = df_auto['normalized-losses'].fillna(df_auto['normalized-losses'].median())
# Out:
# /tmp/ipykernel_8630/4150212120.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_auto['normalized-losses'] = df_auto['normalized-losses'].fillna(df_auto['normalized-losses'].median())

# %%
df_auto['num-of-doors'] = df_auto['num-of-doors'].fillna(df_auto['num-of-doors'].mode()[0])
# Out:
# /tmp/ipykernel_8630/3839306754.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_auto['num-of-doors'] = df_auto['num-of-doors'].fillna(df_auto['num-of-doors'].mode()[0])

# %%
df_auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 201 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  201 non-null    float64
#  2   make               201 non-null    object
#  3   fuel-type          201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num-of-doors       201 non-null    object
#  6   body-style         201 non-null    object
#  7   drive-wheels       201 non-null    object
#  8   engine-location    201 non-null    object
#  9   wheel-base         201 non-null    float64
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb-weight        201 non-null    int64
#  14  engine-type        201 non-null    object
#  15  num-of-cylinders   201 non-null    object
# ...

# %%
korelasi = df_auto.select_dtypes('number').corr()

plt.figure(figsize=(12, 8))
sns.heatmap(korelasi, annot=True, cmap='coolwarm')
plt.title('Peta korelasi fitur pada mobil vs harga')
# Out:
# Text(0.5, 1.0, 'Peta korelasi fitur pada mobil vs harga')

# %%
df_auto = df_auto.fillna(df_auto['horsepower'].median())

# %%
df_auto.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

fitur = ['horsepower', 'engine-size', 'curb-weight', 'width', 'length', 'city-mpg', 'highway-mpg']
x = df_auto[fitur]
y = df_auto['price']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
len(x_train), len(x_test), len(y_train)
# Out:
# (160, 41, 160)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score

model_lr = LinearRegression()
model_lr.fit(x_train, y_train)

model_rf = RandomForestRegressor(random_state=42)
model_rf.fit(x_train, y_train)

predict_lr = model_lr.predict(x_test)
predict_rf = model_rf.predict(x_test)

score_r2 = r2_score(y_test, predict_lr)
mae = mean_absolute_error(y_test, predict_lr)

score_r2_rf = r2_score(y_test, predict_rf)
mae_rf = mean_absolute_error(y_test, predict_rf)


print(f"R2 Score : {score_r2:.4f}") 
print(f'MAE : {mae:.4f}')

print(f"R2 Score Random Forest : {score_r2_rf:.4f}") 
print(f'MAE Random Forest: {mae_rf:.4f}')

#hasil tebakan 
hasil = pd.DataFrame({'asli ': y_test, 'tebakan lr ': predict_lr, 'tebakan rf ': predict_rf})
hasil
# Out:
# R2 Score : 0.7621
# MAE : 3788.5916
# R2 Score Random Forest : 0.9368
# MAE Random Forest: 1766.3427
#        asli    tebakan lr    tebakan rf
# 98    8249.0   6845.023787   7273.296667
# 16   41315.0  24935.001892  31474.210000
# 31    6855.0   6643.394872   6212.900000
# 162   9258.0   7764.445003   8117.510000
# 132  11850.0  13433.948655  13066.045000
# 118   5572.0   5705.473716   5859.140000
# 72   35056.0  28613.370469  32110.380000
# 175   9988.0  12268.900010  10600.263333
# 179  15998.0  20426.467116  17546.470000
# 48   35550.0  31025.639253  34284.030000
# 69   28176.0  22782.524074  23442.200000
# 187   9495.0   8125.920577   8902.910000
# 169   9989.0  14626.319534  10742.515000
# 81    8499.0  11423.245919   8881.920000
# 191  13295.0  15030.679396  15214.087500
# 182   7775.0   7787.599578   7984.040000
# 59    8845.0  12083.955281  10256.910000
# 156   6938.0   7600.320245   7549.350000
# 85    6989.0  11490.892768   8881.720000
# ...
